# %% [markdown]
# # Basic bartorch Demo

# %% [markdown]
# This notebook demonstrates the basic bartorch workflow:
# generating a Shepp-Logan phantom, computing its k-space via FFT,
# and reconstructing it with PICS.
#
# The cells below are stubs — run them once `bartorch` is installed
# (with or without the C++ extension).

# %%
import bartorch as bt
import bartorch.ops as ops

# Generate a Shepp-Logan phantom
# ph = ops.phantom([256, 256])
# print("Shape:", ph.shape)

# %% [markdown]
# > **Note:** See the `attic/demos/` folder for the original legacy demos
# > that use the old SWIG-based `bartpy` interface.
